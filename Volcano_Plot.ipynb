# %%
# !pip install bioinfokit
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
from bioinfokit import analys, visuz

# %%
df = pd.read_csv("/content/volcano.csv")
df
# Out:
#        Unnamed: 0     Gene      l2fc            pv
# 0               0     Xkr4 -6.357552  9.238197e-13
# 1               1  Gm37381  0.000000  0.000000e+00
# 2               2      Rp1      -inf  3.175154e-01
# 3               3    Rp1-1  0.000000  0.000000e+00
# 4               4    Sox17  0.000000  0.000000e+00
# ...           ...      ...       ...           ...
# 27993       27993  Gm28672  0.000000  0.000000e+00
# 27994       27994  Gm28670  0.000000  0.000000e+00
# 27995       27995  Gm29504  0.000000  0.000000e+00
# 27996       27996  Gm20837  0.000000  0.000000e+00
# 27997       27997    Erdr1 -0.265189  7.197543e-02
#
# [27998 rows x 4 columns]

# %%
visuz.GeneExpression.volcano(df=df, lfc='l2fc', pv='pv', geneid="Gene", genenames=("Xkr4", "Rp1", "Erdr1", "Gm28672"), gstyle=2)
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# ...
